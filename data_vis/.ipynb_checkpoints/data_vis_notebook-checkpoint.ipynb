# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import matplotlib.transforms as tran
import sys
import collections
from decimal import Decimal
import pandas as pd
from astropy.io import fits
from astropy.io import ascii as astro_write
from astropy.table import Table, Column
plt.rcParams['figure.figsize'] = [10, 5]

# %%
print(sys.version)
# Out:
# 3.10.2 (tags/v3.10.2:a58ebcc, Jan 17 2022, 14:12:15) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# `FullDataset` is used for storing the model spectra data for all abundances and microturbulence values in a grid for a given T_eff and log G. `get_micro_abund_storage` returns a spectra for a given mt vel/abund from the full dataset.

# %%
class FullDataset:
    def __init__(self, filename, eff_temp=-1.0, log_g=-1.0):
                self.eff_temp = eff_temp
                self.log_g = log_g
                self.storage, self.error_storage = self.read_data(filename)
    def read_data(self, filename):#stored in dict, first num indicates the micro/abund combo, second indicates ionization stage, third is the line location
        f = open(filename, "r")
        f_lines = f.readlines()
        f.close()
        storage = dict()
        error_storage=dict()
        for i in range(27):
                storage[i]=dict()
                error_storage[i]=dict()
        # 12-Line location, 4-EW, 13-Transition 
        read_cols = [13, 12, 4]
        start_ind=0
        start_str=f_lines[0]
        while start_str[0:11] !="!       XST":
            start_ind+=1  
            start_str=f_lines[start_ind]
        print(start_ind)
        count=0
        for l in f_lines[start_ind+1:]:
            line = l.split()
            # if labeled species
            if len(line) > 13 and '(' in line[13]:
                    k = line[13][:line[13].index('(')]
                    if not k in storage[count%27]:
                            storage[count%27][k] = dict()
                            error_storage[count%27][k] = dict()
                    storage[count%27][k][float(line[12])]=float(line[4])
                    error_storage[count%27][k][float(line[12])]=float(line[5])
            count+=1
        return storage, error_storage
    def get_micro_abund_storage(self, micro, abund):#returns sub-dict of micro/abund combo
        abund=str(abund)
        abund_convert={"":0,"C/2":1,"C*2":2,"N/2":3,"N*2":4,"O/2":5,"O*2":6,"SI/2":7,"SI*2":8}
        if micro == 1:
            if abund.isdigit():
                return self.storage[0+int(abund)]
            else:
                return self.storage[0+abund_convert[abund]]
        elif micro == 3:
            if abund.isdigit():
                return self.storage[9+int(abund)]
            else:
                return self.storage[9+abund_convert[abund]]
        elif micro == 5:
            if abund.isdigit():
                return self.storage[18+int(abund)]
            else:
                return self.storage[18+abund_convert[abund]]
        else:
                print("Error: incorrect microturbulence value entered")
                sys.exit(0)
    def get_micro_abund_error_storage(self, micro, abund):#returns sub-dict of micro/abund combo
        abund=str(abund)
        abund_convert={"":0,"C/2":1,"C*2":2,"N/2":3,"N*2":4,"O/2":5,"O*2":6,"SI/2":7,"SI*2":8}
        if micro == 1:
            if abund.isdigit():
                return self.error_storage[0+int(abund)]
            else:
                return self.error_storage[0+abund_convert[abund]]
        elif micro == 3:
            if abund.isdigit():
                return self.error_storage[9+int(abund)]
            else:
                return self.error_storage[9+abund_convert[abund]]
        elif micro == 5:
            if abund.isdigit():
                return self.error_storage[18+int(abund)]
            else:
                return self.error_storage[18+abund_convert[abund]]
        else:
                print("Error: incorrect microturbulence value entered")
                sys.exit(0)

# %% [markdown]
# `ObsDataset` is also a storage class for the observed data, with one variable storing ew values and one storing error values.

# %%
class ObsDataset:
    def __init__(self, filename):
            self.storage, self.error_storage = self.read_data(filename)
    def read_data(self, filename):
            f = open(filename, "r")
            f_lines = f.readlines()
            f.close()
            storage = dict()
            error_storage = dict()
            # 12-Line location, 4-EW, 13-Transition
            read_cols = [13, 12, 4]
            for l in f_lines[4:]:
                    line = l.split()
                    # if labeled species
                    if len(line) > 13 and '(' in line[13]:
                            k = line[13][:line[13].index('(')]
                            if not k in storage:
                                    storage[k] = dict()
                                    error_storage[k]=dict()
                            storage[k][float(line[12])]=float(line[4])
                            error_storage[k][float(line[12])]=float(line[5])
            return storage, error_storage

# %% [markdown]
# `get_ionization_counts` counts the number of lines for each ionization species present and shared by both an observed dataset and a model dataset.

# %%
def get_ionization_counts(obs_dataset, other_dataset):
    count_dict={}    
    for species in obs_dataset:
            if species in other_dataset:
                if species not in count_dict:
                    count_dict[species]=0
                for line in obs_dataset[species]:
                    if line in other_dataset[species]:
                        count_dict[species]=count_dict[species]+1
    return count_dict

# %% [markdown]
# `chi_component` runs a single squared error calculation which can be summed to get a full $\chi^2$ value.

# %%
def chi_component(obs_val, mod_val, error):
    return ((obs_val-mod_val)/(error*obs_val))**2

# %% [markdown]
# `get_chi_val` and `get_chi_val_interp` both calculate the chi-value sums for both interpolated and non-interpolated EW values.

# %%
def get_chi_val(obs_dataset, other_dataset):
    sum = 0.0
    #count_dict = get_ionization_counts(obs_dataset,other_dataset)
    for species in obs_dataset.storage:
            if species in other_dataset and species != "Ca2":#ignore telluric calcium line
                for line in obs_dataset.storage[species]:
                    if line in other_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset[species][line]
                        sum += chi_component(ew1,ew2,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans
def get_chi_val_interp(obs_dataset, other_dataset1, other_dataset2):
    sum = 0.0
    #count_dict = get_ionization_counts(obs_dataset,other_dataset1)
    for species in obs_dataset.storage:
        if species in other_dataset1 and species in other_dataset2 and species != "Ca2":
            for line in obs_dataset.storage[species]:
                if line in other_dataset1[species] and line in other_dataset2[species]:
                    ew1 = obs_dataset.storage[species][line]
                    ew2 = other_dataset1[species][line]
                    ew3 = other_dataset2[species][line]
                    ex = float((ew2+ew3)/2)
                    sum += chi_component(ew1,ex,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans
def get_chi_val_interp_double(obs_dataset, other_dataset1, other_dataset2, other_dataset3, other_dataset4):
    sum = 0.0
    #count_dict = get_ionization_counts(obs_dataset,other_dataset1)
    for species in obs_dataset.storage:
        if species in other_dataset1 and species in other_dataset2 and species in other_dataset3 and species in other_dataset4 and species != "Ca2":
            for line in obs_dataset.storage[species]:
                if line in other_dataset1[species] and line in other_dataset2[species] and line in other_dataset3[species] and line in other_dataset4[species]:
                    ew1 = obs_dataset.storage[species][line]
                    ew2 = other_dataset1[species][line]
                    ew3 = other_dataset2[species][line]
                    ew4 = other_dataset1[species][line]
                    ew5 = other_dataset2[species][line]
                    ex1 = float((ew2+ew3)/2)
                    ex2 = float((ew4+ew5)/2)
                    ex = float((ex1+ex2)/2)
                    sum += chi_component(ew1,ex,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans

# %%
def get_chi_val_filter(obs_dataset, other_dataset, species_list):
    sum = 0.0
    #count_dict = get_ionization_counts(obs_dataset,other_dataset)
    for species in obs_dataset.storage:
            if species in other_dataset and species in species_list:
                for line in obs_dataset.storage[species]:
                    if line in other_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset[species][line]
                        sum += chi_component(ew1,ew2,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans
def get_chi_val_interp_filter(obs_dataset, other_dataset1, other_dataset2, species_list):
    sum = 0.0
    #count_dict = get_ionization_counts(obs_dataset,other_dataset1)
    for species in obs_dataset.storage:
        if species in other_dataset1 and species in other_dataset2 and species in species_list:
            for line in obs_dataset.storage[species]:
                if line in other_dataset1[species] and line in other_dataset2[species]:
                    ew1 = obs_dataset.storage[species][line]
                    ew2 = other_dataset1[species][line]
                    ew3 = other_dataset2[species][line]
                    ex = float((ew2+ew3)/2)
                    sum += chi_component(ew1,ex,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans

# %% [markdown]
# `plot_chi_wavelength` plots the chi-square value for each line over the full wavelength with blue points indicating model values greater than observed, and red points indicating the opposite.

# %%
def plot_chi_wavelength(obs_dataset, other_dataset,filter_list=None):#obs_storage, other_dataset.storage list
        pos_x_vals = []
        pos_y_vals = []
        pos_species_line = []
        neg_x_vals = []
        neg_y_vals = []
        neg_species_line = []

        #count_dict = get_ionization_counts(obs_dataset,other_dataset)
        #print(count_dict)
        for species in obs_dataset.storage:
            if filter_list == None and species in other_dataset:
                for line in obs_dataset.storage[species]:
                    if line in other_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset[species][line]
                        if (ew1-ew2)>=0.0:
                            neg_x_vals.append(line)
                            neg_y_vals.append(chi_component(ew1,ew2,obs_dataset.error_storage[species][line]))
                            neg_species_line.append(species+" "+str(line))
                        else:
                            pos_x_vals.append(line)
                            pos_y_vals.append(chi_component(ew1,ew2,obs_dataset.error_storage[species][line]))
                            pos_species_line.append(species+" "+str(line))
            elif species in filter_list and species in other_dataset:
                for line in obs_dataset.storage[species]:
                    if line in other_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset[species][line]
                        if (ew1-ew2)>=0.0:
                            neg_x_vals.append(line)
                            neg_y_vals.append(chi_component(ew1,ew2,obs_dataset.error_storage[species][line]))
                            neg_species_line.append(species+" "+str(line))
                        else:
                            pos_x_vals.append(line)
                            pos_y_vals.append(chi_component(ew1,ew2,obs_dataset.error_storage[species][line]))
                            pos_species_line.append(species+" "+str(line))
            else:
                continue
        plt.figure(figsize=(12,6))
        plt.scatter(pos_x_vals,pos_y_vals,c='blue',label="Overestimate")
        for i, txt in enumerate(pos_species_line):
            plt.annotate(txt,(pos_x_vals[i],pos_y_vals[i]),xytext=(0.0,65.0),textcoords='offset points',rotation=90)
        plt.scatter(neg_x_vals,neg_y_vals,c='red',label="Underestimate")
        for i, txt in enumerate(neg_species_line):
            plt.annotate(txt,(neg_x_vals[i],neg_y_vals[i]),xytext=(0.0,65.0),textcoords='offset points',rotation=90)
        plt.axhline(y = 0.0, color = 'black', linestyle = 'dashed')
        #plt.xlim([4200,4400])
        #plt.ylim([-1,20])
        plt.xlabel("Wavelength (Angstroms)")
        plt.ylabel("Chi-square contribution")
        plt.legend(loc ="upper right")
        
        plt.show()

# %% [markdown]
# `plot_error_ew` plots the observed error values as a function of EW values on a logarithmic scale.

# %%
def plot_error_ew(obs_dataset):#obs_storage, other_dataset.storage list 
        x_vals = []
        y_vals = []

        #print(count_dict)
        ews = obs_dataset.storage
        errors = obs_dataset.error_storage
        for species in ews:
                for line in ews[species]:
                        x_vals.append(ews[species][line])
                        y_vals.append(errors[species][line])
        plt.scatter(x_vals,y_vals,c='blue')
        plt.xlabel("EW (mA)")
        plt.ylabel("Error (%)")
        plt.xscale("log")
        plt.show()

# %% [markdown]
# `get_chi_val_abund` and `get_chi_val_abund_interp` run the chi-square calculations for the abundance replacement chi-square calculations.

# %%
def get_chi_val_abund(obs_dataset, mod_dataset, mt, abund):
    sum = 0.0
    other_dataset = mod_dataset.get_micro_abund_storage(mt,abund)
    #count_dict = get_ionization_counts(obs_dataset,other_dataset)
    for species in obs_dataset.storage:
            if species in other_dataset and (species == "C2" or species == "CIII" or species == "CIV"):
                carbon_dataset = mod_dataset.get_micro_abund_storage(mt,"C*2")
                for line in obs_dataset.storage[species]:
                    if line in carbon_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = carbon_dataset[species][line]
                        sum += chi_component(ew1,ew2,obs_dataset.error_storage[species][line])
            elif species in other_dataset and species != "Ca2":
                for line in obs_dataset.storage[species]:
                    if line in other_dataset[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset[species][line]
                        sum += chi_component(ew1,ew2,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans
def get_chi_val_abund_interp(obs_dataset, mod_dataset, mt, abund):
    sum = 0.0
    other_dataset_1 = mod_dataset.get_micro_abund_storage(mt-1,abund)
    other_dataset_2 = mod_dataset.get_micro_abund_storage(mt+1,abund)
    #count_dict = get_ionization_counts(obs_dataset,other_dataset_1)
    for species in obs_dataset.storage:
           if species in other_dataset_1 and species in other_dataset_2 and (species == "C2" or species == "CIII" or species == "CIV"):
                carbon_dataset_1 = mod_dataset.get_micro_abund_storage(mt-1,"C*2")
                carbon_dataset_2 = mod_dataset.get_micro_abund_storage(mt+1,"C*2")
                for line in obs_dataset.storage[species]:
                    if line in carbon_dataset_1[species] and line in carbon_dataset_2[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = carbon_dataset_1[species][line]
                        ew3 = carbon_dataset_2[species][line]
                        ex = float((ew2+ew3)/2)
                        sum += chi_component(ew1,ex,obs_dataset.error_storage[species][line])
           elif species in other_dataset_1 and species in other_dataset_2 and species != "Ca2":
                for line in obs_dataset.storage[species]:
                    if line in other_dataset_1[species] and line in other_dataset_2[species]:
                        ew1 = obs_dataset.storage[species][line]
                        ew2 = other_dataset_1[species][line]
                        ew3 = other_dataset_2[species][line]
                        ex = float((ew2+ew3)/2)
                        sum += chi_component(ew1,ex,obs_dataset.error_storage[species][line])
    ans = round(sum,2)
    return ans

# %% [markdown]
# `plot_best_fit_abund_chi_value` returns a table with the best mt/abundance combo marked in green based on the chi-square value with a given abundance replacement.

# %%
def plot_abund_chi_square(obs_dataset, mod_dataset):
    txt_table=[[],[],[],[],[]]#5 mt rows, 9 abund cols
    for i in range(1,6):
        if i in [1,3,5]:
            for j in range(9):
                txt_table[i-1].append(get_chi_val_abund(obs_dataset,mod_dataset,i,j))
        else:
            for j in range(9):
                txt_table[i-1].append(get_chi_val_abund_interp(obs_dataset,mod_dataset,i,j))

    colors=[[],[],[],[],[]]
    lowest_val = 10000000000000
    lowest_indexes = (0,0)
    for mt in range(5):
        for abund in range(9):
            if(txt_table[mt][abund]<lowest_val):
                lowest_val=txt_table[mt][abund]
                lowest_indexes=(mt,abund)
            colors[mt].append("white")
    colors[lowest_indexes[0]][lowest_indexes[1]]='green'
    return (txt_table, colors)

# %% [markdown]
# `plot_chi_square` returns a table with the best mt/abundance combo marked in green based on the chi-square value.

# %%
def plot_chi_square(obs_dataset,mod_dataset):
    txt_table=[[],[],[],[],[]]#5 mt rows, 9 abund cols
    for i in range(1,6):
        if i in [1,3,5]:
            for j in range(9):
                txt_table[i-1].append(get_chi_val(obs_dataset,mod_dataset.get_micro_abund_storage(i,j)))
        else:
            for j in range(9):
                txt_table[i-1].append(get_chi_val_interp(obs_dataset,mod_dataset.get_micro_abund_storage(i-1,j),mod_dataset.get_micro_abund_storage(i+1,j)))

    colors=[[],[],[],[],[]]
    lowest_val = 10000000000000
    lowest_indexes = (0,0)
    for mt in range(5):
        for abund in range(9):
            if(txt_table[mt][abund]<lowest_val):
                lowest_val=txt_table[mt][abund]
                lowest_indexes=(mt,abund)
            colors[mt].append("white")
    colors[lowest_indexes[0]][lowest_indexes[1]]='green'
    #for row_ind, row in enumerate(txt_table):
    #    for col_ind, i in enumerate(row):
    #        txt_table[row_ind][col_ind]='%.2E' % Decimal(i)
    return (txt_table, colors)

# %%
def plot_chi_square_filter(obs_dataset,mod_dataset):
    txt_table=[[],[],[],[],[]]#5 mt rows, 9 abund cols
    #helper_dict = ["C2","CIII","CIV"],["OIII","O2","OIV"],["SkIII","SkIV"],["HeI"],["HI"]
    filter_list = ["OIII","O2","OIV"]
    for i in range(1,6):
        if i in [1,3,5]:
            for j in range(9):
                txt_table[i-1].append(get_chi_val_filter(obs_dataset,mod_dataset.get_micro_abund_storage(i,j),filter_list))
        else:
            for j in range(9):
                txt_table[i-1].append(get_chi_val_interp_filter(obs_dataset,mod_dataset.get_micro_abund_storage(i-1,j),mod_dataset.get_micro_abund_storage(i+1,j),filter_list))

    colors=[[],[],[],[],[]]
    lowest_val = 10000000000000
    lowest_indexes = (0,0)
    for mt in range(5):
        for abund in range(9):
            if(txt_table[mt][abund]<lowest_val):
                lowest_val=txt_table[mt][abund]
                lowest_indexes=(mt,abund)
            colors[mt].append("white")
    colors[lowest_indexes[0]][lowest_indexes[1]]='green'
    #for row_ind, row in enumerate(txt_table):
    #    for col_ind, i in enumerate(row):
    #        txt_table[row_ind][col_ind]='%.2E' % Decimal(i)
    return (txt_table, colors)

# %% [markdown]
# `plot_chi_table` takes the output from the previous two functions and plots the tables on screen.

# %%
def plot_chi_table(obs_dataset, table_func, mod_dataset_list):
        fig = plt.figure(1,figsize=(11,7))
        ax_main = fig.add_subplot(111) #setup main figure and subplot
        count=1
        min_val, max_val = 100000000000000.0,0.0#ignore this loop, just for highlighting min chi value
        for mod_dataset in mod_dataset_list:
            ax_data = table_func(obs_dataset, mod_dataset)
            df=pd.DataFrame(ax_data[0])
            if min_val>df.values.min():
                min_val=df.values.min()
            if max_val<df.values.max():
                max_val=df.values.max()
        for mod_dataset in mod_dataset_list:#iterate over the models
            if count==3:#skips certain table matrix positions for missing data
                count=4
            if count==10:
                count=11
            ax = fig.add_subplot(4,3,count)#look at the add_subplot documentation, 1st num is rows #, 2nd is cols #, 3 is the position in the table matrix (left to right, then top to bottom, 1-indexed)
            ax.axis("off")
            ax.axis("tight")
            ax_data = table_func(obs_dataset, mod_dataset)
            df = pd.DataFrame(ax_data[0],index=["MT1", "MT2", "MT3", "MT4", "MT5"],columns=["---","C/2","C*2","N/2","N*2","O/2","O*2","SI/2","SI*2"]) #using the dataframe to have row and col labels for subtables, might be better way to do this
            norm = plt.Normalize(min_val, max_val)
            colors = plt.cm.summer_r(norm(df.values))
            tbl = ax.table(cellText=df.values,cellColours=colors,rowLabels=df.index, colLabels=df.columns,loc='center',cellLoc='center')#note that i'm using ax.table instead of plt.table here
            font_size=7
            tbl.auto_set_font_size(False)
            tbl.set_fontsize(font_size)
            tbl.scale(1,1.2)#plot the table and run visual functions on it
            count+=1
        ax_main.spines['top'].set_color('none')#more visual things
        ax_main.spines['bottom'].set_color('none')
        ax_main.spines['left'].set_color('none')
        ax_main.spines['right'].set_color('none')
        ax_main.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)
        ax_main.set_xlabel('Log G: 3.5 - 3.7')#labels for the main table axes
        ax_main.set_ylabel('T_Eff: 2.6 - 2.75')
        fig.tight_layout()
        fig.subplots_adjust(hspace=0.1)
        plt.show()

# %%
def line_comparison_plot(obs_dataset, mod_full_dataset_list, species):
    num_spaces = 5
    plt.figure(figsize=(12,6))
    fig, ax = plt.subplots(111)
    for i in range(3+num_spaces):#logg
        for j in range(3+num_spaces):#teff
            return null

# %% [markdown]
# `check_ew_comparison` lists all lines where the inequality $EW/2 < EW < EW*2$ doesn't hold.

# %%
def check_ew_comparison(mod_full_dataset):
     helper_dict = {1:["C2","CIII","CIV"],3:["NIII"],5:["OIII","O2","OIV"],7:["SkIII","SkIV"]}
     for mt_val in range(1,7,2):
        for abund_val in range(1,8,2):
            other_dataset_norm = mod_full_dataset.get_micro_abund_error_storage(mt_val,0)
            other_dataset_half = mod_full_dataset.get_micro_abund_error_storage(mt_val,abund_val)
            other_dataset_double = mod_full_dataset.get_micro_abund_error_storage(mt_val,abund_val+1)
            for species in other_dataset_norm:
                if species in other_dataset_half and species in other_dataset_double:
                    for line in other_dataset_norm[species]:
                        if line in other_dataset_half[species] and line in other_dataset_double[species]:
                            ew_norm = other_dataset_norm[species][line]
                            ew_half = other_dataset_half[species][line]
                            ew_double = other_dataset_double[species][line]
                            if (species in helper_dict[abund_val]) and (ew_half>ew_norm or ew_norm>ew_double):
                                print("MT: "+str(mt_val)+" Species: "+str(species)+" Line: "+str(line))
                                print("EW/2: "+str(ew_half)+" EW: "+str(ew_norm)+" EW*2: "+str(ew_double))

# %%
def sanity_check(obs_dataset):
    count_dict={}    
    for species in obs_dataset:
        if species not in count_dict:
            count_dict[species]=0
        for line in obs_dataset[species]:
            count_dict[species]=count_dict[species]+1
    return count_dict

# %% [markdown]
# Read in all datasets.

# %%
obs_dataset = ObsDataset("EW_DATA_REDUX2")

mod_dataset_1 = FullDataset("EW_DATA_FULL_3p52p75")
mod_dataset_2 = FullDataset("EW_DATA_FULL_3p62p75")
mod_dataset_3 = FullDataset("EW_DATA_FULL_3p52p7")
mod_dataset_4 = FullDataset("EW_DATA_FULL_3p62p7")
mod_dataset_5 = FullDataset("EW_DATA_FULL_3p72p7")
mod_dataset_6 = FullDataset("EW_DATA_FULL_3p52p6")
mod_dataset_7 = FullDataset("EW_DATA_FULL_3p62p6")
mod_dataset_8 = FullDataset("EW_DATA_FULL_3p72p6")
mod_dataset_9 = FullDataset("EW_DATA_FULL_3p62p5")
mod_dataset_10 = FullDataset("EW_DATA_FULL_3p52p8")
mod_dataset_11 = FullDataset("EW_DATA_FULL_3p62p8")
mod_dataset_12 = FullDataset("EW_DATA_FULL_3p72p8")
# Out:
# 29
# 29
# 29
# 29
# 29
# 31
# 29
# 29
# 29
# 31
# 31
# 31

# %%
plot_chi_table(obs_dataset, plot_chi_square_filter, [mod_dataset_1, mod_dataset_2,mod_dataset_3,mod_dataset_4,mod_dataset_5,mod_dataset_6,mod_dataset_7,mod_dataset_8,mod_dataset_9])

# %%
print(sanity_check(obs_dataset.storage))
# Out:
# {'OIII': 1, 'O2': 53, 'SkIII': 5, 'HeI': 12, 'HI': 1, 'Ca2': 1, 'SkIV': 2, 'C2': 1, 'CIII': 2}

# %%
def graph_t_log_g(obs_dataset, mod_dataset_list,mod_dataset_list_teff,sk4=4090.016,sk3=4569.121):
    fig, ax1 = plt.subplots()

    color_g='red'
    ax1.set_xlabel('Log_G', color=color_g)
    ax1.set_ylabel('ew ratio SKIV/SKIII')
    


    ax2 = ax1.twiny()  # instantiate a second axes that shares the same x-axis

    color_t = 'blue'
    ax2.set_xlabel('Teff', color=color_t)  # we already handled the x-label with ax1
    
    #["SkIII","SkIV"]
    log_dict = {0:3.5,1:3.6,2:3.7}
    log_g_x = []
    log_g_y = []
    teff_dict = {0:2.6,1:2.7,2:2.8}
    teff_x = []
    teff_y = []
    count=0
    for dataset in mod_dataset_list:
        if count>0:
            if int(count%3)==0:
                #print(log_g_x)
                ax1.plot(log_g_x, log_g_y, color=color_g,marker='o',alpha=0.5)
                log_g_x = []
                log_g_y = []
        store = dataset.get_micro_abund_storage(1,3)
        if "SkIV" in store:
            if 4090.016 in store["SkIV"]:
                if "SkIII" in store:
                    if 4569.121 in store["SkIII"]:
                        line1=store["SkIV"][4090.016]
                        line2=store["SkIII"][4569.121]
                        log_g_x.append(log_dict[count%3])
                        log_g_y.append(float(line1)/float(line2))
        
        count+=1
    ax1.plot(log_g_x, log_g_y, color=color_g,marker='o',alpha=0.5)
        
    log_dict = {0:3.5,1:3.6,2:3.7}
    log_g_x = []
    log_g_y = []
    teff_dict  = {0:2.6,1:2.7,2:2.8}
    teff_x = []
    teff_y = []
    count=0
    for dataset in mod_dataset_list_teff:
        if count>0:
            if int(count%3)==0:
                ax2.plot(teff_x, teff_y, color=color_t,marker='x',alpha=0.5)
                teff_x = []
                teff_y = []
        store = dataset.get_micro_abund_storage(1,3)
        if "SkIV" in store:
            if sk4 in store["SkIV"]:
                if "SkIII" in store:
                    if sk3 in store["SkIII"]:
                        line1=store["SkIV"][sk4]
                        line2=store["SkIII"][sk3]
                        teff_x.append(teff_dict[int(count%3)])
                        teff_y.append(float(line1)/float(line2))
        
        count+=1
    ax2.plot(teff_x, teff_y, color=color_t,marker='x',alpha=0.5)

    ax1.tick_params(axis='x', labelcolor=color_g)
    ax2.tick_params(axis='x', labelcolor=color_t)

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    #ax1.xlim()
    plt.show()

# %%
print(mod_dataset_10.get_micro_abund_storage(1,3)['SkIII'])
print(mod_dataset_11.get_micro_abund_storage(1,3)['SkIII'])
print(mod_dataset_12.get_micro_abund_storage(1,3)['SkIII'])
print(mod_dataset_10.get_micro_abund_storage(1,3)['SkIV'])
print(mod_dataset_11.get_micro_abund_storage(1,3)['SkIV'])
print(mod_dataset_12.get_micro_abund_storage(1,3)['SkIV'])
# Out:
# {3807.606: 29.61, 4553.898: 78.52, 4569.121: 62.88, 4576.039: 32.82}
# {3807.606: 32.53, 4553.898: 79.2, 4569.121: 63.19, 4576.039: 33.33}
# {3807.606: 35.29, 4553.898: 79.64, 4569.121: 64.03, 4576.039: 33.91}
# {3763.517: 16.97, 4090.016: 92.04, 4117.265: 74.47}
# {3763.517: 16.63, 4090.016: 82.54, 4117.265: 66.6}
# {3763.517: 15.9, 4090.016: 74.45, 4117.265: 59.26}

# %%
graph_t_log_g(obs_dataset, [mod_dataset_6,mod_dataset_7,mod_dataset_8,mod_dataset_3,mod_dataset_4,mod_dataset_5,mod_dataset_10,mod_dataset_11,mod_dataset_12],[mod_dataset_6,mod_dataset_3,mod_dataset_10,mod_dataset_7,mod_dataset_4,mod_dataset_11,mod_dataset_8,mod_dataset_5,mod_dataset_12])

# %%
graph_t_log_g(obs_dataset, [mod_dataset_6,mod_dataset_7,mod_dataset_8,mod_dataset_3,mod_dataset_4,mod_dataset_5,mod_dataset_10,mod_dataset_11,mod_dataset_12],[mod_dataset_6,mod_dataset_3,mod_dataset_10,mod_dataset_7,mod_dataset_4,mod_dataset_11,mod_dataset_8,mod_dataset_5,mod_dataset_12],sk4=4117.265)

# %%
plot_chi_wavelength(obs_dataset,mod_dataset_6.get_micro_abund_storage(1,"C/2"),filter_list=["SkIII","SkIV"])

# %%
plot_chi_wavelength(obs_dataset,mod_dataset_6.get_micro_abund_storage(1,"SI*2"),filter_list=["SkIII","SkIV"])

# %%
plot_chi_wavelength(obs_dataset,mod_dataset_6.get_micro_abund_storage(1,"SI*2"))

# %%
print(mod_dataset_6.get_micro_abund_storage(1,"")["SkIII"])
print(mod_dataset_6.get_micro_abund_storage(1,"C/2")["SkIII"])
# Out:
# {3792.516: 17.56, 3807.606: 60.89, 4553.898: 130.3, 4569.121: 102.69, 4576.039: 54.69}
# {3792.516: 15.73, 3807.606: 50.06, 4553.898: 95.47, 4569.121: 78.54, 4576.039: 45.73}

# %% [markdown]
# # New XShooter Data

# %% [markdown]
# Read in all the FITS files and convert them to Hillier format(TM).

# %%
def read_fits_file(filename, name_list):
    hdul = fits.open(filename)
    for i in range(1,len(hdul)):
        data = hdul[i].data
        col_list = [0,2,3,16,17]
        f_str_list = ['%-f','%-E','%-E','%-f','%-f']
        data_table = np.column_stack(tuple(map(lambda v:data.field(v),col_list)))
        data_table = Table(data_table, names=(hdul[i].columns.names[k] for k in col_list))
        f = open(name_list[i-1],"w")
        f.write("FLUX_UNIT_2=ergs/cm^2/s/Ang\n")
        f.write("FLUX_UNIT_3=ergs/cm^2/s/Ang\n")
        f.write("FLUX_UNIT_4=Norm\n")
        f.write("FLUX_UNIT_5=Norm\n")
        f.write("WAVE_UNIT=Angstroms\n")
        f.write("AIR_LAM=False\n")
        astro_write.write(data_table, f, format='fixed_width_no_header',delimiter='',col_starts=[2,29,66,93,120],col_ends=[27,64,91,118,145],formats={hdul[i].columns.names[k]:f_str_list[j] for j,k in enumerate(col_list)})
        f.close()

# %%
read_fits_file("XSH-U_AV304_INDIV1D.fits",['XSH_UV1','XSH_UV2','XSH_VIS1','XSH_VIS2'])

# %%
hdul = fits.open("AV304_CLA_MI_18dec2022_norm.fits")
hdul.info()
# Out:
# Filename: AV304_CLA_MI_18dec2022_norm.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     107   (174380,)   float32

# %%
hdul = fits.open("AV304_CLA_MI_18dec2022_merged.fits")
#hdul.info()
data = hdul[0].data
header = hdul[0].header
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    1 / Number of axes
# NAXIS1  =               174379 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2023-06-30T15:37:03' / Date FITS file was generated
# IRAF-TLM= '2023-06-30T15:37:03' / Time of last modification
# OBJECT  = 'AV304   '           / Name of the object observed
# BUNIT   = 'erg/cm2/s/A'
# SITENAME= 'LCO'
# SITEALT =                 2405         / meters
# SITELAT =            -29.01423
# SITELONG=            -70.69242
# TELESCOP= 'Clay_Mag_2'                 / telescope
# OBSERVER= 'Nidia Morrell'              / observer name
# DATE-OBS= '2022-12-18T02:58:14'        / (start)
# UT-DATE = '2022-12-18'                 / UT date (start)
# UT-START= '02:58:14'
# UT-TIME =                10694         / '02:58:14' UT time (start)
# LC-START= '23:58:14'
# LC-TIME =                86294         / '23:58:14' local time (start)
# TIMEZONE=                    4
# INSTRUME= 'MIKE-Blue'                  / instrument name
# SCALE   =               0.2608         / arcsec/pixel
# EGAIN   =                 0.47         / electrons/DU
# ENOISE  =                 2.70         / electrons/read
# BIASLINS=                  128
# RA      = ' 01:02:20.7'                / right ascension
# RA-D    =           15.5863333         / [degrees] ( 01:02:20.7)
# DEC     = '-72:39:08.3'                / declination
# DEC-D   =          -72.6523056         / [degrees] (-72:39:08.3)
# EQUINOX =           2000.00000         / of above coordinates
# EPOCH   =           2022.96198         / epoch (start)
# AIRMASS =                1.543 / airmass (start)
# ST      =              14538.8         / sidereal time:  4:02:19 (start)
# HA      = '+02:59:58.1'                / hour angle (E<0)
# PARASTRT=               54.907         / paralactic angle (start)
# PARA-END=               64.847         / paracactic angle (end)
# SLTASTRT=               74.485         / slit angle (start)
# SLTA-END=               86.953         / slit angle (end)
# TEMPDOME=                 13.0         / temperature dome [C]
# TEMPCELL=                 11.6         / temperature cell [C]
# TEMPOUTS=                 12.0         / temperature outside [C]
# TEMPINST=                 13.9         / instrument temperature [C]
# FILENAME= 'b0063'
# EXPTYPE = 'Object'                     / exposure type
# FILTER  =                              / filter
# CAMCOM  =                              / camera comment
# EXPTIME =                2400. / exposure time
# NLOOPS  =                    1         / # of loops per sequence
# LOOP    =                    1         / # within this sequence
# BINNING = '2x2'                        / binning
# SPEED   = 'Slow'                       / readout speed
# SUBRASTR= 'none'                       / full frame
# SLITSIZE= '0.70x5.00'                  / slit size
# CFOCUS  =               1141.6         / camera focus
# GRAT-AZ =                 0.38         / grating azimuth
# GRAT-EL =                 0.54         / grating elevation
# CAL-LAMP= 'off'                        / lamp
# TEMPCCD =                157.4         / CCD temperature [C]
# INSTCOM =                              / instrument comment
# CONFIG  =                              / camera configuration
# ADC     = 'in/auto'                    / ADC status (stage/control)
# SOFTWARE= 'Version 3.1.2 (0057) (Mar  4 2022, 07:30:47)'
# FITSVERS= '3.0'                        / FITS header version
# COMMENT
# WCSDIM  =                    1
# LTM1_1  =                   1.
# WAT0_001= 'system=equispec'
# WAT1_001= 'wtype=linear label=Wavelength units=Angstroms'
# TRIM    = 'Jun  8 17:57 Trim data section is [1:1024,1:2048]'
# OVERSCAN= 'Jun  8 17:57 Overscan section is [1:1024,2060:2170] with mean=733.10'
# ZEROCOR = 'Jun  8 17:57 Zero level correction image is Zerob'
# FLATCOR = 'Jun  8 17:57 Flat field image is nmilkyb with scale=0.9979485'
# CCDSEC  = '[1:1024,1:2048]'
# CCDMEAN =             127.2441
# CCDMEANT=           1370714261
# CCDPROC = 'Jun  8 17:57 CCD processing done'
# DISPAXIS=                    1 /
# BANDID1 = 'spectrum - background average                                       '
# CTYPE1  = 'LINEAR  '           /
# CDELT1  =   0.0342592952253871 /
# CD1_1   =   0.0342592952253871 /
# DCLOG1  = 'REFSPEC1 = zb0062.ec'
# EX-FLAG =                    0
# CA-FLAG =                    0
# NCOMBINE=                    2
# CRPIX1  =                   1.
# APNUM1  = '1 103 1.00 1.00'
# DC-FLAG =                    0
# CRVAL1  =           3435.28125

# %%
plt.figure(figsize=(12,6))
plt.plot([(x*header['CDELT1'])+header['CRVAL1'] for x in range(len(data))],data,linewidth=0.1)
plt.xlim([4000,4500])
plt.show()
hdul.close()
#read_fits_file("AV304_CLA_MI_18dec2022_merged.fits")

# %%
def read_fits_file_pain(filename, name_list):
    hdul = fits.open(filename)
    data = hdul[0].data
    header = hdul[0].header
    wv_list = [(x*header['CDELT1'])+header['CRVAL1'] for x in range(len(data))]
    f_str_list = ['%-f','%-E']
    data_table = np.column_stack((np.array(wv_list).T,np.array(data).T))
    data_table = Table(data_table, names=('WAVELENGTH','FLUX'))
    f = open(name_list[0],"w")
    f.write("FLUX_UNIT=ergs/cm^2/s/Ang\n")
    f.write("WAVE_UNIT=Angstroms\n")
    f.write("AIR_LAM=False\n")
    astro_write.write(data_table, f, format='fixed_width_no_header',delimiter='',col_starts=[2,29],col_ends=[27,64],formats={'WAVELENGTH':'%-f','FLUX':'%-E'})
    f.close()

# %%
read_fits_file_pain("AV304_CLA_MI_18dec2022_merged.fits",['AV304_HI_RES_MERGED'])

# %%
hdul = fits.open("AV304_CLA_MI_18dec2022_norm.fits")
data = hdul[0].data
header = hdul[0].header
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    1 / Number of axes
# NAXIS1  =               174380 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2023-06-30T18:24:53' / Date FITS file was generated
# IRAF-TLM= '2023-06-30T18:24:53' / Time of last modification
# OBJECT  = 'AV304   '           / Name of the object observed
# BUNIT   = 'erg/cm2/s/A'
# SITENAME= 'LCO'
# SITEALT =                 2405         / meters
# SITELAT =            -29.01423
# SITELONG=            -70.69242
# TELESCOP= 'Clay_Mag_2'                 / telescope
# OBSERVER= 'Nidia Morrell'              / observer name
# DATE-OBS= '2022-12-18T02:58:14'        / (start)
# UT-DATE = '2022-12-18'                 / UT date (start)
# UT-START= '02:58:14'
# UT-TIME =                10694         / '02:58:14' UT time (start)
# LC-START= '23:58:14'
# LC-TIME =                86294         / '23:58:14' local time (start)
# TIMEZONE=                    4
# INSTRUME= 'MIKE-Blue'                  / instrument name
# SCALE   =               0.2608         / arcsec/pixel
# EGAIN   =                 0.47         / electrons/DU
# ENOISE  =                 2.70         / electrons/read
# BIASLINS=                  128
# RA      = ' 01:02:20.7'                / right ascension
# RA-D    =           15.5863333         / [degrees] ( 01:02:20.7)
# DEC     = '-72:39:08.3'                / declination
# DEC-D   =          -72.6523056         / [degrees] (-72:39:08.3)
# EQUINOX =           2000.00000         / of above coordinates
# EPOCH   =           2022.96198         / epoch (start)
# AIRMASS =                1.543 / airmass (start)
# ST      =              14538.8         / sidereal time:  4:02:19 (start)
# HA      = '+02:59:58.1'                / hour angle (E<0)
# PARASTRT=               54.907         / paralactic angle (start)
# PARA-END=               64.847         / paracactic angle (end)
# SLTASTRT=               74.485         / slit angle (start)
# SLTA-END=               86.953         / slit angle (end)
# TEMPDOME=                 13.0         / temperature dome [C]
# TEMPCELL=                 11.6         / temperature cell [C]
# TEMPOUTS=                 12.0         / temperature outside [C]
# TEMPINST=                 13.9         / instrument temperature [C]
# FILENAME= 'b0063'
# EXPTYPE = 'Object'                     / exposure type
# FILTER  =                              / filter
# CAMCOM  =                              / camera comment
# EXPTIME =                2400. / exposure time
# NLOOPS  =                    1         / # of loops per sequence
# LOOP    =                    1         / # within this sequence
# BINNING = '2x2'                        / binning
# SPEED   = 'Slow'                       / readout speed
# SUBRASTR= 'none'                       / full frame
# SLITSIZE= '0.70x5.00'                  / slit size
# CFOCUS  =               1141.6         / camera focus
# GRAT-AZ =                 0.38         / grating azimuth
# GRAT-EL =                 0.54         / grating elevation
# CAL-LAMP= 'off'                        / lamp
# TEMPCCD =                157.4         / CCD temperature [C]
# INSTCOM =                              / instrument comment
# CONFIG  =                              / camera configuration
# ADC     = 'in/auto'                    / ADC status (stage/control)
# SOFTWARE= 'Version 3.1.2 (0057) (Mar  4 2022, 07:30:47)'
# FITSVERS= '3.0'                        / FITS header version
# COMMENT
# WCSDIM  =                    1
# LTM1_1  =                   1.
# WAT0_001= 'system=equispec'
# WAT1_001= 'wtype=linear label=Wavelength units=Angstroms'
# TRIM    = 'Jun  8 17:57 Trim data section is [1:1024,1:2048]'
# OVERSCAN= 'Jun  8 17:57 Overscan section is [1:1024,2060:2170] with mean=733.10'
# ZEROCOR = 'Jun  8 17:57 Zero level correction image is Zerob'
# FLATCOR = 'Jun  8 17:57 Flat field image is nmilkyb with scale=0.9979485'
# CCDSEC  = '[1:1024,1:2048]'
# CCDMEAN =             127.2441
# CCDMEANT=           1370714261
# CCDPROC = 'Jun  8 17:57 CCD processing done'
# DISPAXIS=                    1 /
# BANDID1 = 'spectrum - background average                                       '
# CTYPE1  = 'LINEAR  '           /
# CDELT1  =   0.0342590987608171 /
# CD1_1   =   0.0342590987608171 /
# DCLOG1  = 'REFSPEC1 = zb0062.ec'
# EX-FLAG =                    0
# CA-FLAG =                    0
# NCOMBINE=                   23
# CRPIX1  =                   1.
# APNUM1  = '14 90 1.00 1.00'
# DC-FLAG =                    0
# CRVAL1  =           3435.28125

# %%
read_fits_file_pain("AV304_CLA_MI_18dec2022_norm.fits",['AV304_HI_RES_NORM'])

# %%
hi_res_obs_dataset = ObsDataset("EW_DATA_HI_RES_NORM")

# %%
print(sanity_check(obs_dataset.storage))
print(sanity_check(hi_res_obs_dataset.storage))
# Out:
# {'OIII': 1, 'O2': 53, 'SkIII': 5, 'HeI': 12, 'HI': 1, 'Ca2': 1, 'SkIV': 2, 'C2': 1, 'CIII': 2}
# {'HeI': 15, 'O2': 37, 'SkIV': 1, 'C2': 3, 'SkIII': 3, 'CIII': 1, 'HI': 3}

# %%
plot_chi_table(hi_res_obs_dataset, plot_chi_square, [mod_dataset_1, mod_dataset_2,mod_dataset_3,mod_dataset_4,mod_dataset_5,mod_dataset_6,mod_dataset_7,mod_dataset_8])

# %% [markdown]
# ![](h_lines.png)

# %%
def read_balmer_data(filename):#stored in dict, first num indicates the micro/abund combo, second indicates ionization stage, third is the line location
        f = open(filename, "r")
        f_lines = f.readlines()
        f.close()
        storage = list()
        #storage = dict()
        read_cols = [13, 12, 4]
        start_ind=0
        start_str=f_lines[0]
        while start_str[0] == "!":
            start_ind+=1  
            start_str=f_lines[start_ind]
        #print(start_ind)
        for l in f_lines[start_ind:]:
            line = l.split()
            if len(line)>=7:
                #storage[float(line[1][0:4])]=float(line[6])
                storage.append(float(line[6]))
        return storage

# %%
def get_micro_abund_storage_bal(storage, micro, abund):#returns sub-dict of micro/abund combo
        abund=str(abund)
        abund_convert={"":0,"C/2":1,"C*2":2,"N/2":3,"N*2":4,"O/2":5,"O*2":6,"SI/2":7,"SI*2":8}
        if micro == 1:
            if abund.isdigit():
                return storage[0+int(abund)]
            else:
                return storage[0+abund_convert[abund]]
        elif micro == 3:
            if abund.isdigit():
                return storage[9+int(abund)]
            else:
                return storage[9+abund_convert[abund]]
        elif micro == 5:
            if abund.isdigit():
                return storage[18+int(abund)]
            else:
                return storage[18+abund_convert[abund]]
        else:
                print("Error: incorrect microturbulence value entered")
                sys.exit(0)

# %%
print(read_balmer_data("bal_data/BAL_FDATA_2p63p6")[0])
print(read_balmer_data("bal_data/BAL_FDATA_2p63p6_2"))
# Out:
# 3.419
# [2.09, 1.873, 17.899]

# %%
mod_baldata_vis_1 = read_balmer_data("bal_data/BAL_FDATA_2p93p5")
mod_baldata_vis_2 = read_balmer_data("bal_data/BAL_FDATA_2p93p6")
mod_baldata_vis_3 = read_balmer_data("bal_data/BAL_FDATA_2p93p7")
mod_baldata_vis_4 = read_balmer_data("bal_data/BAL_FDATA_2p93p8")
mod_baldata_vis_5 = read_balmer_data("bal_data/BAL_FDATA_2p83p5")
mod_baldata_vis_6 = read_balmer_data("bal_data/BAL_FDATA_2p83p6")
mod_baldata_vis_7 = read_balmer_data("bal_data/BAL_FDATA_2p83p7")
mod_baldata_vis_8 = read_balmer_data("bal_data/BAL_FDATA_2p83p8")
mod_baldata_vis_9 = read_balmer_data("bal_data/BAL_FDATA_2p83p9")
mod_baldata_vis_10 = read_balmer_data("bal_data/BAL_FDATA_2p73p5")
mod_baldata_vis_11 = read_balmer_data("bal_data/BAL_FDATA_2p73p6")
mod_baldata_vis_12 = read_balmer_data("bal_data/BAL_FDATA_2p73p7")
mod_baldata_vis_13 = read_balmer_data("bal_data/BAL_FDATA_2p73p8")
mod_baldata_vis_14 = read_balmer_data("bal_data/BAL_FDATA_2p63p5")
mod_baldata_vis_15 = read_balmer_data("bal_data/BAL_FDATA_2p63p6")
mod_baldata_vis_16 = read_balmer_data("bal_data/BAL_FDATA_2p63p7")
mod_baldata_vis_17 = read_balmer_data("bal_data/BAL_FDATA_2p63p8")
mod_baldata_vis_18 = read_balmer_data("bal_data/BAL_FDATA_2p53p6")
mod_baldata_vis = [mod_baldata_vis_1,mod_baldata_vis_2,mod_baldata_vis_3,mod_baldata_vis_4,mod_baldata_vis_5,mod_baldata_vis_6,mod_baldata_vis_7,mod_baldata_vis_8,mod_baldata_vis_9,mod_baldata_vis_10,mod_baldata_vis_11,mod_baldata_vis_12,mod_baldata_vis_13,mod_baldata_vis_14,mod_baldata_vis_15,mod_baldata_vis_16,mod_baldata_vis_17,mod_baldata_vis_18]

mod_baldata_uv_1 = read_balmer_data("bal_data/BAL_FDATA_2p93p5_2")
mod_baldata_uv_2 = read_balmer_data("bal_data/BAL_FDATA_2p93p6_2")
mod_baldata_uv_3 = read_balmer_data("bal_data/BAL_FDATA_2p93p7_2")
mod_baldata_uv_4 = read_balmer_data("bal_data/BAL_FDATA_2p93p8_2")
mod_baldata_uv_5 = read_balmer_data("bal_data/BAL_FDATA_2p83p5_2")
mod_baldata_uv_6 = read_balmer_data("bal_data/BAL_FDATA_2p83p6_2")
mod_baldata_uv_7 = read_balmer_data("bal_data/BAL_FDATA_2p83p7_2")
mod_baldata_uv_8 = read_balmer_data("bal_data/BAL_FDATA_2p83p8_2")
mod_baldata_uv_9 = read_balmer_data("bal_data/BAL_FDATA_2p83p9_2")
mod_baldata_uv_10 = read_balmer_data("bal_data/BAL_FDATA_2p73p5_2")
mod_baldata_uv_11 = read_balmer_data("bal_data/BAL_FDATA_2p73p6_2")
mod_baldata_uv_12 = read_balmer_data("bal_data/BAL_FDATA_2p73p7_2")
mod_baldata_uv_13 = read_balmer_data("bal_data/BAL_FDATA_2p73p8_2")
mod_baldata_uv_14 = read_balmer_data("bal_data/BAL_FDATA_2p63p5_2")
mod_baldata_uv_15 = read_balmer_data("bal_data/BAL_FDATA_2p63p6_2")
mod_baldata_uv_16 = read_balmer_data("bal_data/BAL_FDATA_2p63p7_2")
mod_baldata_uv_17 = read_balmer_data("bal_data/BAL_FDATA_2p63p8_2")
mod_baldata_uv_18 = read_balmer_data("bal_data/BAL_FDATA_2p53p6_2")
mod_baldata_uv = [mod_baldata_uv_1,mod_baldata_uv_2,mod_baldata_uv_3,mod_baldata_uv_4,mod_baldata_uv_5,mod_baldata_uv_6,mod_baldata_uv_7,mod_baldata_uv_8,mod_baldata_uv_9,mod_baldata_uv_10,mod_baldata_uv_11,mod_baldata_uv_12,mod_baldata_uv_13,mod_baldata_uv_14,mod_baldata_uv_15,mod_baldata_uv_16,mod_baldata_uv_17,mod_baldata_uv_18]

# %%
mod_baldata_1 = read_balmer_data("bal_data/BAL_DATA_2p93p5")
mod_baldata_2 = read_balmer_data("bal_data/BAL_DATA_2p93p6")
mod_baldata_3 = read_balmer_data("bal_data/BAL_DATA_2p93p7")
mod_baldata_4 = read_balmer_data("bal_data/BAL_DATA_2p93p8")
mod_baldata_5 = read_balmer_data("bal_data/BAL_DATA_2p83p5")
mod_baldata_6 = read_balmer_data("bal_data/BAL_DATA_2p83p6")
mod_baldata_7 = read_balmer_data("bal_data/BAL_DATA_2p83p7")
mod_baldata_8 = read_balmer_data("bal_data/BAL_DATA_2p83p8")
mod_baldata_9 = read_balmer_data("bal_data/BAL_DATA_2p83p9")
mod_baldata_10 = read_balmer_data("bal_data/BAL_DATA_2p73p5")
mod_baldata_11 = read_balmer_data("bal_data/BAL_DATA_2p73p6")
mod_baldata_12 = read_balmer_data("bal_data/BAL_DATA_2p73p7")
mod_baldata_13 = read_balmer_data("bal_data/BAL_DATA_2p73p8")
mod_baldata_14 = read_balmer_data("bal_data/BAL_DATA_2p63p5")
mod_baldata_15 = read_balmer_data("bal_data/BAL_DATA_2p63p6")
mod_baldata_16 = read_balmer_data("bal_data/BAL_DATA_2p63p7")
mod_baldata_17 = read_balmer_data("bal_data/BAL_DATA_2p63p8")
mod_baldata_18 = read_balmer_data("bal_data/BAL_DATA_2p53p6")
mod_baldata = [mod_baldata_1,mod_baldata_2,mod_baldata_3,mod_baldata_4,mod_baldata_5,mod_baldata_6,mod_baldata_7,mod_baldata_8,mod_baldata_9,mod_baldata_10,mod_baldata_11,mod_baldata_12,mod_baldata_13,mod_baldata_14,mod_baldata_15,mod_baldata_16,mod_baldata_17,mod_baldata_18]

# %%
def plot_chi_square_bal(mod_datasets_vis, mod_datasets_uv, line_ind):
    
    line_id_trans = {1:6565.0,2:4862.0,3:4341.0,4:4103.0}
    txt_table=[[],[],[],[],[]]#5 temp rows, 5 log g cols
    count, data_ind=0,0
    while count<5*5:
        #print(data_ind)
        if count==4 or count==14 or count==19 or count==20 or count>21:
            txt_table[int(count/5)].append(None)
            #print("blank")
            count+=1
        else:
            if line_ind>1:
                txt_table[int(count/5)].append(mod_datasets_uv[data_ind][line_ind-2])
            else:
                #print(mod_datasets_vis[data_ind])
                txt_table[int(count/5)].append(mod_datasets_vis[data_ind][line_ind-1])
            count+=1
            data_ind+=1
    fig = plt.figure(1,figsize=(6,3))
    ax_main = fig.add_subplot(111) 
    #fig, ax = plt.subplots()
    df=pd.DataFrame(txt_table)
    min_val=np.nanmin(df.values)
    max_val=np.nanmax(df.values)
    
    #print(min_val)
    ax = fig.add_subplot(111)
    
    fig.patch.set_visible(False)
    ax.axis("off")
    ax.axis("tight")
    df = pd.DataFrame(txt_table,index=["2.9","2.8","2.7","2.6","2.5"],columns=["3.5","3.6","3.7","3.8","3.9"]) 
    df = df.div(min_val)
    df = df.round(3)
    norm = plt.Normalize(min_val/min_val, max_val/min_val)
    colors = plt.cm.summer_r(norm(df.values))
    tbl = ax.table(cellText=df.values,cellColours=colors,rowLabels=df.index, colLabels=df.columns,loc='center',cellLoc='center')
    font_size=12
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(font_size)
    tbl.scale(1,1)
    
    
    
    ax_main.spines['top'].set_color('none')
    ax_main.spines['bottom'].set_color('none')
    ax_main.spines['left'].set_color('none')
    ax_main.spines['right'].set_color('none')
    ax_main.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

    ax_main.set_xlabel(r'log g [dex]')
    ax_main.set_ylabel(r'T$_{eff}$[10$^{5}$K]')
    
    # hide axes
    fig.tight_layout()
    plt.show()

# %%
def plot_chi_square_bal_new(mod_datasets, line_ind):
    
    line_id_trans = {1:6565.0,2:4862.0,3:4341.0,4:4103.0}
    txt_table=[[],[],[],[],[]]#5 temp rows, 5 log g cols
    count, data_ind=0,0
    while count<5*5:
        #print(data_ind)
        if count==4 or count==14 or count==19 or count==20 or count>21:
            txt_table[int(count/5)].append(None)
            #print("blank")
            count+=1
        else:
            txt_table[int(count/5)].append(mod_datasets[data_ind][line_ind-1])
            count+=1
            data_ind+=1
    fig = plt.figure(1,figsize=(6,3))
    ax_main = fig.add_subplot(111) 
    #fig, ax = plt.subplots()
    df=pd.DataFrame(txt_table)
    min_val=np.nanmin(df.values)
    max_val=np.nanmax(df.values)
    
    #print(min_val)
    ax = fig.add_subplot(111)
    
    fig.patch.set_visible(False)
    ax.axis("off")
    ax.axis("tight")
    df = pd.DataFrame(txt_table,index=["2.9","2.8","2.7","2.6","2.5"],columns=["3.5","3.6","3.7","3.8","3.9"]) 
    #df = df.div(min_val)
    df = df.round(3)
    norm = plt.Normalize(min_val/min_val, max_val/min_val)
    colors = plt.cm.summer_r(norm(df.values))
    tbl = ax.table(cellText=df.values,cellColours=colors,rowLabels=df.index, colLabels=df.columns,loc='center',cellLoc='center')
    font_size=12
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(font_size)
    tbl.scale(1,1)
    
    
    
    ax_main.spines['top'].set_color('none')
    ax_main.spines['bottom'].set_color('none')
    ax_main.spines['left'].set_color('none')
    ax_main.spines['right'].set_color('none')
    ax_main.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)

    ax_main.set_xlabel(r'log g [dex]')
    ax_main.set_ylabel(r'T$_{eff}$[10$^{5}$K]')
    
    # hide axes
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ![](bal_pic.png)

# %%
plot_chi_square_bal_new(mod_baldata,1)
plot_chi_square_bal_new(mod_baldata,2)
plot_chi_square_bal_new(mod_baldata,3)

# %%
plot_chi_square_bal(mod_baldata_vis,mod_baldata_uv,1)

# %%
plot_chi_square_bal_new(mod_baldata,2)

# %%
plot_chi_square_bal(mod_baldata_vis,mod_baldata_uv,2)

# %%
plot_chi_square_bal_new(mod_baldata,3)

# %%
plot_chi_square_bal(mod_baldata_vis,mod_baldata_uv,3)
